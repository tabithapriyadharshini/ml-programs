# %%
import json

# Open JSON file
with open("student_data.json", "r") as file:
    data = json.load(file)

# Display the data
print(data)
# Out:
# {'name': 'Sukumar', 'age': 22, 'course': 'MCA', 'marks': 85}
