# %%
import pandas as pd

# Create dataset
data = {
    "Name": ["Sukumar", "Rahul", "Kiran", "Arjun"],
    "City": ["Hyderabad", "Chennai", "Hyderabad", "Delhi"],
    "Marks": [85, 78, 92, 65]
}

df = pd.DataFrame(data)

# Replace Hyderabad with Bangalore
df["City"] = df["City"].replace("Hyderabad", "Bangalore")

print(df)
# Out:
#       Name       City  Marks
# 0  Sukumar  Bangalore     85
# 1    Rahul    Chennai     78
# 2    Kiran  Bangalore     92
# 3    Arjun      Delhi     65
