# %%
import pandas as pd

# Load CSV file
data = pd.read_csv("student_dataset.csv")

# Display the data
print(data)
# Out:
#     Student_ID  Age  Study_Hours  Attendance  Marks
# 0            1   23          2.9          71     46
# 1            2   25          5.7          86    100
# 2            3   23          3.9          97     80
# 3            4   20          5.5          79     74
# 4            5   24          1.8          60     54
# 5            6   21          7.1          85     95
# 6            7   18          4.7          65     63
# 7            8   18          3.7          76     89
# 8            9   23          6.8          80     80
# 9           10   22          7.9          79     58
# 10          11   23          5.5          98     41
# 11          12   19          2.5          77     59
# 12          13   22          1.8          77     75
# 13          14   19          6.4          82     96
# 14          15   22          3.0          82    100
# 15          16   20          1.9          89     68
# 16          17   19          6.1          95     81
# 17          18   18          6.3          91     88
# 18          19   19          4.7         100     64
# 19          20   21          2.4          73     61

# %%
import pandas as pd

# Load CSV file
data = pd.read_csv("student_dataset.csv")

print("CSV file loaded successfully!\n")

print("First 5 rows:")
print(data.head())

print("\nNumber of rows and columns:")
print(data.shape)

print("\nColumn names:")
print(data.columns)
# Out:
# CSV file loaded successfully!
#
# First 5 rows:
#    Student_ID  Age  Study_Hours  Attendance  Marks
# 0           1   23          2.9          71     46
# 1           2   25          5.7          86    100
# 2           3   23          3.9          97     80
# 3           4   20          5.5          79     74
# 4           5   24          1.8          60     54
#
# Number of rows and columns:
# (20, 5)
#
# Column names:
# Index(['Student_ID', 'Age', 'Study_Hours', 'Attendance', 'Marks'], dtype='object')
